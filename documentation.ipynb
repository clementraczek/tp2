# %% [markdown]
# # 🎬 TP Docker – Films
#
# Ce projet a pour objectif de manipuler des données de films à l’aide de deux services Docker :
#
# - **write** → permet d’ajouter, modifier et supprimer des films dans un fichier `movies.csv`.
# - **read** → permet de lire et filtrer ces films selon plusieurs critères.
#
# Les deux services communiquent à travers un **volume Docker partagé** contenant le fichier `movies.csv`.
#
# ---
#
# ## 🗂️ Contenu du notebook
# 1. Récupération du projet depuis GitHub
# 2. Lancement du projet sous Docker
# 3. Utilisation des applications
# 4. Cas d’erreurs et exceptions
# 5. Conclusion

# %% [markdown]
# ## 1️⃣ Récupération du projet (Git)
#
# Avant de commencer, assurez-vous d’avoir **Git** installé sur votre machine.
#
# Clonez le dépôt Git contenant le projet :

# %%
# Clonage du repository Git
# !git clone https://github.com/clementraczek/tp2.git

# Vérification du contenu du dossier
# !ls -R
# Out:
# c:\Users\Administrateur\OneDrive - M2I\Bureau\tp\.ipynb_checkpoints\tp2\tp2
# Cloning into 'tp2'...
# 'ls' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex�cutable ou un fichier de commandes.

# %%
# Lancement des conteneurs en mode interactif
# !docker-compose up -d
# Out:
# #1 [internal] load local bake definitions
# #1 reading from stdin 1.18kB 0.0s done
# #1 DONE 0.0s
#
# #2 [write_app internal] load build definition from dockerfile
# #2 transferring dockerfile: 148B 0.0s done
# #2 DONE 0.0s
#
# #3 [read_app internal] load build definition from dockerfile
# #3 transferring dockerfile: 148B 0.0s done
# #3 DONE 0.1s
#
# #4 [read_app internal] load metadata for docker.io/library/python:latest
# #4 DONE 0.8s
#
# #5 [write_app internal] load .dockerignore
# #5 transferring context: 2B done
# #5 DONE 0.0s
#
# #6 [read_app internal] load .dockerignore
# #6 transferring context: 2B done
# #6 DONE 0.1s
#
# #7 [read_app internal] load build context
# #7 transferring context: 4.89kB done
# #7 DONE 0.0s
#
# #8 [read_app 1/3] FROM docker.io/library/python:latest@sha256:1ad1a43b5e2478e62056bbc28028afd858185d73bf4d6a439cbb058b6800a96d
# #8 resolve docker.io/library/python:latest@sha256:1ad1a43b5e2478e62056bbc28028afd858185d73bf4d6a439cbb058b6800a96d 0.1s done
# ...

# %% [markdown]
# Vous devriez voir deux conteneurs :
# - `tp-write` : service de manipulation des films (écriture)
# - `tp-read` : service de lecture et filtrage des films
#
# Les deux utilisent le **volume partagé `data_volume`** pour échanger le fichier `movies.csv`.

# %%
# Exemple : exécuter le script manip_data.py dans le conteneur write
# !docker exec -it tp-write python manip_data.py
# Out:
# Error response from daemon: No such container: tp-write
